# %% [markdown]
# Installing necessary libraries

# %%
# !pip install request
# !pip install bs4    #beautiful soup
# !pip install html5lib  #html parser
# Out:
# ERROR: Could not find a version that satisfies the requirement request
# ERROR: No matching distribution found for request
# ...
#      |████████████████████████████████| 115 kB 4.4 MB/s eta 0:00:01
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=ba384682055ab595e87e80e5672757d6a6427eb4e50ee379b7065a1bff4fad32
#   Stored in directory: /home/jovyan/.cache/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# Successfully built bs4
# ...
#      |████████████████████████████████| 112 kB 4.4 MB/s eta 0:00:01
# ...
